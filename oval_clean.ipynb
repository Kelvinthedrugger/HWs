# %%
#default_exp core

# %% [markdown]
# # **Learn nbdev !!!!!**

# %%
""" Maths are alright, but the axes length are still weird """
# Out:
# ' Maths are alright, but the axes length are still weird '

# %%
# export
import numpy as np
from matplotlib import pyplot as plt

# %%
# export
# the cov matrix
# sig1 = 2, sig2 = 1, rho = 0.5
cov = [[4,1],[1,1]]

# %%
# export
# get the points first makes more sense
numpts = 2000
Points = np.random.multivariate_normal([0,0],cov,size=numpts)

# %%
# plot the darn thing
plt.scatter(Points[:,0],Points[:,1])
plt.title("Raw points to have a look quickly")
# Out:
# Text(0.5, 1.0, 'Raw points to have a look quickly')

# %%
# export
# get vector length
def vlen(v):
    return np.sqrt( np.square(v[-2]) + np.square(v[-1]))

# try it
vlen(np.array([1,2])), vlen(np.array([3,4]))
# Out:
# (2.23606797749979, 5.0)

# %%
# export
# get the eigvals and vecs
eigvals, eigvecs = np.linalg.eig(np.array(cov))
eigvals, eigvecs
# Out:
# (array([4.30277564, 0.69722436]),
#  array([[ 0.95709203, -0.28978415],
#         [ 0.28978415,  0.95709203]]))

# %%
eigvecs.T[0]
# Out:
# array([0.95709203, 0.28978415])

# %%
# confirm it's an eigenvector
eigvals[0] * eigvecs[0],np.array(cov) @ (eigvecs.T[0])
# Out:
# (array([ 4.11815225, -1.24687618]), array([4.11815225, 1.24687618]))

# %%
# export
major = eigvecs.T[0]
major
# Out:
# array([0.95709203, 0.28978415])

# %%
# export
minor = eigvecs.T[1]
minor
# Out:
# array([-0.28978415,  0.95709203])

# %%
# export
# find the angle of major axis to x axis
# take advantage of high school math: dot product
x_vec = np.array([1,0])
dot = major @ x_vec
ang = np.arccos(dot/(vlen(major)*vlen(x_vec)))
ang * 180 / np.pi
# Out:
# 16.845033762989885

# %% [markdown]
# # Is the length correct ?
#
# ### should be proportional to sqrt(eigvals) !

# %% [markdown]
# #### Since std_x = 2 instead of 1, the modified overall std = sqrt(std_x^2 + std_y^2) = sqrt(5)
#
# #### , which would required us to scale the std by 1/std = 1/sqrt(5)
#
# #### from z-score table, we'll get ratio = 0.59

# %%
# export
""" 0.59 meets but i don't know why """ # gets 0.502
rat = 0.59 # 1/sqrt(5) times of standard deviation !?
major_length = 2*eigvals[0]**0.5 * rat
minor_length = 2*eigvals[1]**0.5 * rat
major_length, minor_length
# Out:
# (2.4476896858012918, 0.9852995493868707)

# %%
# export
# get the ellipse again use high school math
cos = np.cos(ang)
sin = np.sin(ang)

def transform_x(x,y):
    return x*cos + y*sin

def transform_y(x,y):
    return x*sin - y*cos

theta = np.arange(0,360,1)*np.pi/180
x = major_length*np.cos(theta)
y = minor_length*np.sin(theta)

x_oval = transform_x(x,y)
y_oval = transform_y(x,y)

plt.plot(x_oval,y_oval)
plt.show()

# %%
# export
# define boundary and calculate inside/total
Points_map = [[transform_x(ele[0],ele[1]),transform_y(ele[0],ele[1])] for ele in Points]

# %%
# export
def boundary(point):
    return vlen([point[0]*minor_length,point[1]*major_length])

# %%
# export
boundary(Points_map[1])
# Out:
# 0.45000144426611266

# %%
# export
# check if the point is inside the boundary
pts, pts2 = [], []
for i in range(numpts):
    if boundary(Points_map[i]) < major_length*minor_length:
        pts.append(Points[i])
    else:
        pts2.append(Points[i])

# %%
pts[:10]
# Out:
# [array([ 0.3738122 , -0.00733337]),
#  array([-1.82855056, -0.21002012]),
#  array([2.07516408, 0.35539424]),
#  array([1.21471177, 0.59626319]),
#  array([-0.00459439, -0.13725733]),
#  array([-0.27567978,  0.72115983]),
#  array([-1.67877858, -0.38551174]),
#  array([-0.28889873,  0.23709678]),
#  array([-0.84516474,  0.35356821]),
#  array([-0.06116132, -0.58497132])]

# %%
# export
ptsn, ptsn2 = np.array(pts), np.array(pts2)

# %%
len(ptsn)/numpts
# Out:
# 0.492

# %%
plt.scatter(ptsn[:,0],ptsn[:,1])
plt.scatter(ptsn2[:,0],ptsn2[:,1])

# %%
major, minor
# Out:
# (array([0.95709203, 0.28978415]), array([-0.28978415,  0.95709203]))

# %%
# export
# major and minor axis line
xx = np.arange(-8,8,1/numpts)
y1 = xx * major[1]/major[0]
y2 = xx * minor[1]/minor[0]

# %%
# orthogonal
major[1]/major[0] * minor[1]/minor[0]
# Out:
# -1.0

# %%
# print ratio
len(ptsn)/numpts
# Out:
# 0.492

# %%
# export
# result
plt.figure(figsize=(9,9))
plt.plot(x_oval,y_oval,"purple",linewidth=5.0)
plt.scatter(ptsn[:,0],ptsn[:,1])
plt.scatter(ptsn2[:,0],ptsn2[:,1])
plt.plot(xx,y1,"black")
plt.plot(xx,y2,"green")

plt.xlim([-4,4])
plt.ylim([-4,4])
plt.legend(["contour","major","minor","inside","outside"])
plt.title(chr(ord('%')) + "std: %.4f; inside/total: %.4f" % (rat, len(ptsn)/numpts))
# change the filename each time, can use os.scandir() to write the right filename automatically
#plt.savefig('output3')
plt.show()

# %%
# export everything to a python script and save the result

# %% [markdown]
# ## Exploring Chi-squared
# #### F(s) = 1 - exp(-s/2) for bivariate normal distribution

# %%
def chi(s):
    return 1 - np.exp(-s/2)

t = np.arange(0,7,0.01)
plt.plot(t,chi(t))
plt.title("chi-squared")
plt.show()

# %% [markdown]
# ### It turned out, we need chi-squared distribution for non-standard normal distribution
# #### P[x,k,lambda] = exp(-lambda/2) * sum((lambda/2)**j / j! * gamma(k/2,x/2+2j)/gammafunction(k/2)) j from 0 to +inf
# #### https://en.wikipedia.org/wiki/Noncentral_chi-squared_distribution#Cumulative_distribution_function

# %% [markdown]
# #### Would this work?

# %%
#hide
from nbdev.export import notebook2script
notebook2script()
# Out:
# ---------------------------------------------------------------------------
# MissingSectionHeaderError                 Traceback (most recent call last)
# <ipython-input-31-5004f907da3b> in <module>
#       1 #hide
#       2 from nbdev.export import notebook2script
# ----> 3 notebook2script()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\nbdev\export.py in notebook2script(fname, silent, to_dict, bare)
#     422     if os.environ.get('IN_TEST',0): return  # don't export if running tests
#     423     if fname is None:
# --> 424         reset_nbdev_module()
#     425         update_version()
#     426         update_baseurl()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\nbdev\export.py in reset_nbdev_module()
#     241 def reset_nbdev_module():
#     242     "Create a skeleton for <code>_nbdev</code>"
# --> 243     fname = get_config().path("lib_path")/'_nbdev.py'
#     244     fname.parent.mkdir(parents=True, exist_ok=True)
#     245     sep = '\n'* (int(get_config().get('cell_spacing', '1'))+1)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\nbdev\imports.py in get_config(cfg_name)
#      27     cfg_path = Path.cwd()
#      28     while cfg_path != cfg_path.parent and not (cfg_path/cfg_name).exists(): cfg_path = cfg_path.parent
# ---> 29     config = Config(cfg_path, cfg_name=cfg_name)
#      30     _add_new_defaults(config.d, config.config_file,
#      31             host="github", doc_host="https://%(user)s.github.io", doc_baseurl="/%(lib_name)s/")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\fastcore\foundation.py in __init__(self, cfg_path, cfg_name, create)
#     259                 self.save()
#     260             else: raise Exception(f"Could not find {cfg_name}")
# --> 261         self.d = read_config_file(self.config_file)
#     262
#     263     def __setitem__(self,k,v): self.d[k] = str(v)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\fastcore\foundation.py in read_config_file(file, **kwargs)
#     244 def read_config_file(file, **kwargs):
#     245     config = ConfigParser(**kwargs)
# --> 246     config.read(file)
#     247     return config['DEFAULT']
#     248
#
# ~\AppData\Local\Programs\Python\Python37\lib\configparser.py in read(self, filenames, encoding)
#     694             try:
#     695                 with open(filename, encoding=encoding) as fp:
# --> 696                     self._read(fp, filename)
#     697             except OSError:
#     698                 continue
#
# ~\AppData\Local\Programs\Python\Python37\lib\configparser.py in _read(self, fp, fpname)
#    1077                 # no section header in the file?
#    1078                 elif cursect is None:
# -> 1079                     raise MissingSectionHeaderError(fpname, lineno, line)
#    1080                 # an option line?
#    1081                 else:
#
# MissingSectionHeaderError: File contains no section headers.
# file: Path('c:/Users/Kelvin/Desktop/seninfo/MLstat/settings.ini'), line: 1
# 'lib_name = oval_clean\n'
